# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk

# %%
#Importing the CSV dataset as a dataframe
miceData = pd.read_csv("MiceProteinDataSet.csv", sep=',',header=0, decimal='.', encoding='unicode_escape')

# %%
miceData.describe()
# Out:
#           DYRK1A_N      ITSN1_N       BDNF_N        NR1_N       NR2A_N  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000
# mean      0.425810     0.617102     0.319088     2.297269     3.843934
# std       0.249362     0.251640     0.049383     0.347293     0.933100
# min       0.145327     0.245359     0.115181     1.330831     1.737540
# 25%       0.288121     0.473361     0.287444     2.057411     3.155678
# 50%       0.366378     0.565782     0.316564     2.296546     3.760855
# 75%       0.487711     0.698032     0.348197     2.528481     4.440011
# max       2.516367     2.602662     0.497160     3.757641     8.482553
#
#             pAKT_N      pBRAF_N    pCAMKII_N      pCREB_N       pELK_N  ...  \
# count  1077.000000  1077.000000  1077.000000  1077.000000  1077.000000  ...
# mean      0.233168     0.181846     3.537109     0.212574     1.428682  ...
# std       0.041634     0.027042     1.295169     0.032587     0.466904  ...
# ...

# %%
import pandas as pd
import glob

path = r'/home/harindu/Assignment_II/accel_data' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=None)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#                 0     1     2     3  4
# 0             0.0  1502  2215  2153  1
# 1             1.0  1667  2072  2047  1
# 2             2.0  1611  1957  1906  1
# 3             3.0  1601  1939  1831  1
# 4             4.0  1643  1965  1879  1
# ...           ...   ...   ...   ... ..
# 1431437  140900.0  2098  2305  1982  7
# 1431438  140900.0  2106  2314  1980  7
# 1431439  140900.0  2112  2319  1973  7
# 1431440  140900.0  2111  2319  1969  7
# 1431441  140900.0  2110  2312  1972  0
#
# [1431442 rows x 5 columns]

# %%
path = r'/home/harindu/Assignment_II/accel_data'

# %%
import pandas as pd
from glob import glob

# %%
stock_files = sorted(glob('/home/harindu/Assignment_II/accel_data/*.csv'))
stock_files
# Out:
# ['/home/harindu/Assignment_II/accel_data/1.csv',
#  '/home/harindu/Assignment_II/accel_data/11.csv',
#  '/home/harindu/Assignment_II/accel_data/12.csv',
#  '/home/harindu/Assignment_II/accel_data/14.csv',
#  '/home/harindu/Assignment_II/accel_data/15.csv',
#  '/home/harindu/Assignment_II/accel_data/3.csv',
#  '/home/harindu/Assignment_II/accel_data/4.csv',
#  '/home/harindu/Assignment_II/accel_data/5.csv',
#  '/home/harindu/Assignment_II/accel_data/6.csv',
#  '/home/harindu/Assignment_II/accel_data/8.csv',
#  '/home/harindu/Assignment_II/accel_data/9.csv']

# %%
pd.concat((pd.read_csv(file, header = None).assign(filename = file)
           for file in stock_files), ignore_index = True)
# Out:
#                 0     1     2     3  4  \
# 0             0.0  1502  2215  2153  1
# 1             1.0  1667  2072  2047  1
# 2             2.0  1611  1957  1906  1
# 3             3.0  1601  1939  1831  1
# 4             4.0  1643  1965  1879  1
# ...           ...   ...   ...   ... ..
# 1431437  166740.0  2072  2545  2059  7
# 1431438  166740.0  2069  2547  2064  7
# 1431439  166740.0  2069  2542  2062  7
# 1431440  166740.0  2069  2543  2063  7
# 1431441  166740.0  2065  2534  2060  0
#
#                                              filename
# 0        /home/harindu/Assignment_II/accel_data/1.csv
# 1        /home/harindu/Assignment_II/accel_data/1.csv
# 2        /home/harindu/Assignment_II/accel_data/1.csv
# 3        /home/harindu/Assignment_II/accel_data/1.csv
# 4        /home/harindu/Assignment_II/accel_data/1.csv
# ...                                               ...
# 1431437  /home/harindu/Assignment_II/accel_data/9.csv
# ...
